# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Task 1: Financial News Exploratory Data Analysis

# %%
## Objectives
- Analyze financial news headlines
- Identify publishers and trends
- Prepare data for sentiment analysis
# Out:
#   Cell In[1], line 2
#     - Analyze financial news headlines
#               ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Data Loading (To be added when dataset is available)

# %%
# Placeholder for dataset loading
# news = pd.read_csv("data/raw/news.csv")
# news.head()
